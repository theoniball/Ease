# %%
import pandas as pd
import numpy as np

file = "cooper tire kushan 2.xlsx"
df = pd.read_excel(file)
df
# Out:
#    过程分层审核检查表（A表）\nLAYERED PROCESS AUDIT CHECK SHEET  Unnamed: 1  \
# 0                                               NaN         NaN
# 1                                               NaN         NaN
# 2                                               NaN         NaN
# 3                                          部门Dept.:         NaN
# 4                                  审核层次Audit Level:         NaN
# 5                                               NaN         NaN
# 6                                              Item         NaN
# 7                                               NaN         NaN
# 8                                       Section #1:         NaN
# 9                                       个人防护用品\nPPE         NaN
# 10                                             应急响应         NaN
# 11                                              NaN         NaN
# 12                                             危废管理         NaN
# 13                                              NaN         NaN
# ...
